# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 626

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"+ "units=Imperial&"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = url + "&q=" + city.replace(" ","+")
    city_url = url + "appid=" + weather_api_key + "&q=" + city.replace(" ","+") 
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]   
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]  

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | isiro
# Processing Record 3 of Set 1 | sitka
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | ahipara
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | osmena
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | aklavik
# Processing Record 13 of Set 1 | jutai
# Processing Record 14 of Set 1 | katsuura
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | ganzhou
# Processing Record 17 of Set 1 | khani
# Processing Record 18 of Set 1 | leningradskiy
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | sao filipe
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | boa vista
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | kavaratti
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | fairbanks
# Processing Record 31 of Set 1 | mocuba
# Processing Record 32 of Set 1 | huarmey
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | winnipeg
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | adelaide
# Processing Record 37 of Set 1 | margate
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | deniliquin
# Processing Record 40 of Set 1 | lavrentiya
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | estelle
# Processing Record 43 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 1 | ampanihy
# Processing Record 45 of Set 1 | sungaipenuh
# Processing Record 46 of Set 1 | barra do garcas
# Processing Record 47 of Set 1 | bushehr
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | kavieng
# Processing Record 0 of Set 2 | bukan
# Processing Record 1 of Set 2 | traverse city
# Processing Record 2 of Set 2 | bandarbeyla
# Processing Record 3 of Set 2 | mount gambier
# Processing Record 4 of Set 2 | ukiah
# Processing Record 5 of Set 2 | mehamn
# Processing Record 6 of Set 2 | general roca
# Processing Record 7 of Set 2 | port keats
# Processing Record 8 of Set 2 | yumen
# Processing Record 9 of Set 2 | rosario
# Processing Record 10 of Set 2 | akhalgori
# Processing Record 11 of Set 2 | abnub
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | pa sang
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | cairns
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | ostersund
# Processing Record 18 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | namatanai
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | vestmannaeyjar
# Processing Record 23 of Set 2 | araguatins
# City not found. Skipping...
# Processing Record 24 of Set 2 | naze
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | tura
# Processing Record 27 of Set 2 | sawtell
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | portland
# Processing Record 31 of Set 2 | gaogou
# Processing Record 32 of Set 2 | nizhniy odes
# Processing Record 33 of Set 2 | port macquarie
# Processing Record 34 of Set 2 | udachnyy
# Processing Record 35 of Set 2 | barguzin
# Processing Record 36 of Set 2 | hofn
# Processing Record 37 of Set 2 | baijiantan
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | biak
# Processing Record 41 of Set 2 | victoria
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | sorong
# Processing Record 44 of Set 2 | nome
# Processing Record 45 of Set 2 | teguldet
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | gilgit
# Processing Record 49 of Set 2 | butaritari
# Processing Record 0 of Set 3 | ambon
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | prado
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | aasiaat
# Processing Record 5 of Set 3 | necochea
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | torres
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | srednekolymsk
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | guerrero negro
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | evensk
# Processing Record 14 of Set 3 | lexington
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | nazarovo
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | aviles
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | isla vista
# Processing Record 21 of Set 3 | beyneu
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | dolo
# Processing Record 26 of Set 3 | redmond
# Processing Record 27 of Set 3 | la paz
# Processing Record 28 of Set 3 | sur
# Processing Record 29 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 3 | nenjiang
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | asau
# Processing Record 34 of Set 3 | kaitangata
# Processing Record 35 of Set 3 | koraput
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | dikson
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | sao jose da coroa grande
# Processing Record 41 of Set 3 | noumea
# Processing Record 42 of Set 3 | meadow lake
# Processing Record 43 of Set 3 | bababe
# City not found. Skipping...
# Processing Record 44 of Set 3 | qasigiannguit
# Processing Record 45 of Set 3 | tiverton
# Processing Record 46 of Set 3 | hermanus
# Processing Record 47 of Set 3 | geraldton
# Processing Record 48 of Set 3 | lima
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 0 of Set 4 | vila
# Processing Record 1 of Set 4 | laviana
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | simbahan
# Processing Record 4 of Set 4 | tilichiki
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | souillac
# Processing Record 7 of Set 4 | adrar
# Processing Record 8 of Set 4 | camacha
# Processing Record 9 of Set 4 | kroya
# Processing Record 10 of Set 4 | cherskiy
# Processing Record 11 of Set 4 | zyryanka
# Processing Record 12 of Set 4 | henties bay
# Processing Record 13 of Set 4 | muros
# Processing Record 14 of Set 4 | benguela
# Processing Record 15 of Set 4 | baglung
# Processing Record 16 of Set 4 | warrington
# Processing Record 17 of Set 4 | livingstonia
# Processing Record 18 of Set 4 | okha
# Processing Record 19 of Set 4 | urengoy
# Processing Record 20 of Set 4 | new norfolk
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | ridgecrest
# Processing Record 23 of Set 4 | mezen
# Processing Record 24 of Set 4 | lazaro cardenas
# Processing Record 25 of Set 4 | codrington
# Processing Record 26 of Set 4 | half moon bay
# Processing Record 27 of Set 4 | moose factory
# Processing Record 28 of Set 4 | shingu
# Processing Record 29 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 4 | atuona
# Processing Record 31 of Set 4 | ilinskoye-khovanskoye
# Processing Record 32 of Set 4 | luwuk
# Processing Record 33 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 4 | santiago de cao
# Processing Record 35 of Set 4 | gasa
# Processing Record 36 of Set 4 | verdalsora
# City not found. Skipping...
# Processing Record 37 of Set 4 | zilair
# Processing Record 38 of Set 4 | kebemer
# City not found. Skipping...
# Processing Record 39 of Set 4 | nakapiripirit
# Processing Record 40 of Set 4 | wanning
# Processing Record 41 of Set 4 | magugu
# Processing Record 42 of Set 4 | yar-sale
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | aykhal
# Processing Record 45 of Set 4 | coihaique
# Processing Record 46 of Set 4 | bumba
# Processing Record 47 of Set 4 | astana
# Processing Record 48 of Set 4 | iberia
# Processing Record 49 of Set 4 | port hardy
# Processing Record 0 of Set 5 | bengkulu
# Processing Record 1 of Set 5 | luanda
# Processing Record 2 of Set 5 | okhotsk
# Processing Record 3 of Set 5 | botwood
# Processing Record 4 of Set 5 | klaksvik
# Processing Record 5 of Set 5 | waddan
# Processing Record 6 of Set 5 | ambajogai
# Processing Record 7 of Set 5 | mahon
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | grand gaube
# Processing Record 10 of Set 5 | rawson
# Processing Record 11 of Set 5 | strezhevoy
# Processing Record 12 of Set 5 | anadyr
# Processing Record 13 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 15 of Set 5 | campo bom
# Processing Record 16 of Set 5 | constantine
# Processing Record 17 of Set 5 | sinjar
# Processing Record 18 of Set 5 | husavik
# Processing Record 19 of Set 5 | sulphur springs
# Processing Record 20 of Set 5 | tromso
# Processing Record 21 of Set 5 | vertou
# Processing Record 22 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 5 | mount isa
# Processing Record 24 of Set 5 | kruisfontein
# Processing Record 25 of Set 5 | khandyga
# Processing Record 26 of Set 5 | turukhansk
# Processing Record 27 of Set 5 | ozernovskiy
# Processing Record 28 of Set 5 | kakonko
# Processing Record 29 of Set 5 | chapais
# Processing Record 30 of Set 5 | kampot
# Processing Record 31 of Set 5 | heidelberg
# Processing Record 32 of Set 5 | warri
# Processing Record 33 of Set 5 | nanortalik
# Processing Record 34 of Set 5 | zhanaozen
# Processing Record 35 of Set 5 | richards bay
# Processing Record 36 of Set 5 | airai
# Processing Record 37 of Set 5 | mabai
# Processing Record 38 of Set 5 | macau
# Processing Record 39 of Set 5 | salinas
# Processing Record 40 of Set 5 | alofi
# Processing Record 41 of Set 5 | weiser
# Processing Record 42 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | chupaca
# Processing Record 45 of Set 5 | tiksi
# Processing Record 46 of Set 5 | shakhtinsk
# Processing Record 47 of Set 5 | grindavik
# Processing Record 48 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 5 | darnah
# Processing Record 0 of Set 6 | talnakh
# Processing Record 1 of Set 6 | tezu
# Processing Record 2 of Set 6 | nuevitas
# Processing Record 3 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 5 of Set 6 | waipawa
# Processing Record 6 of Set 6 | lianzhou
# Processing Record 7 of Set 6 | constitucion
# Processing Record 8 of Set 6 | derzhavinsk
# Processing Record 9 of Set 6 | shubarshi
# Processing Record 10 of Set 6 | puerto madryn
# Processing Record 11 of Set 6 | punta alta
# Processing Record 12 of Set 6 | obluche
# City not found. Skipping...
# Processing Record 13 of Set 6 | uvinza
# Processing Record 14 of Set 6 | sibolga
# Processing Record 15 of Set 6 | hilo
# Processing Record 16 of Set 6 | bethel
# Processing Record 17 of Set 6 | bredasdorp
# Processing Record 18 of Set 6 | shimoda
# Processing Record 19 of Set 6 | maltahohe
# Processing Record 20 of Set 6 | taboga
# Processing Record 21 of Set 6 | beloha
# Processing Record 22 of Set 6 | morro bay
# Processing Record 23 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 6 | namibe
# Processing Record 25 of Set 6 | salt lake city
# Processing Record 26 of Set 6 | wawa
# Processing Record 27 of Set 6 | sabha
# Processing Record 28 of Set 6 | tiruchchendur
# Processing Record 29 of Set 6 | vardo
# Processing Record 30 of Set 6 | tasiilaq
# Processing Record 31 of Set 6 | gigmoto
# Processing Record 32 of Set 6 | kaeo
# Processing Record 33 of Set 6 | lorengau
# Processing Record 34 of Set 6 | kalengwa
# Processing Record 35 of Set 6 | kushiro
# Processing Record 36 of Set 6 | eenhana
# Processing Record 37 of Set 6 | rumphi
# Processing Record 38 of Set 6 | palana
# Processing Record 39 of Set 6 | san quintin
# Processing Record 40 of Set 6 | north bend
# Processing Record 41 of Set 6 | barentu
# Processing Record 42 of Set 6 | harper
# Processing Record 43 of Set 6 | homer
# Processing Record 44 of Set 6 | georgetown
# Processing Record 45 of Set 6 | nizhniy kuranakh
# Processing Record 46 of Set 6 | ardesen
# Processing Record 47 of Set 6 | namtsy
# Processing Record 48 of Set 6 | yungkang
# City not found. Skipping...
# Processing Record 49 of Set 6 | cockburn town
# Processing Record 0 of Set 7 | karratha
# Processing Record 1 of Set 7 | labuhan
# Processing Record 2 of Set 7 | oussouye
# Processing Record 3 of Set 7 | elizabeth city
# Processing Record 4 of Set 7 | barabinsk
# Processing Record 5 of Set 7 | guanambi
# Processing Record 6 of Set 7 | mayumba
# Processing Record 7 of Set 7 | miyako
# Processing Record 8 of Set 7 | hasaki
# Processing Record 9 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 7 | ludhiana
# Processing Record 11 of Set 7 | maragogi
# Processing Record 12 of Set 7 | ayagoz
# Processing Record 13 of Set 7 | buraydah
# Processing Record 14 of Set 7 | usinsk
# Processing Record 15 of Set 7 | upernavik
# Processing Record 16 of Set 7 | orbetello
# Processing Record 17 of Set 7 | kattivakkam
# Processing Record 18 of Set 7 | bathsheba
# Processing Record 19 of Set 7 | nevesinje
# Processing Record 20 of Set 7 | kununurra
# Processing Record 21 of Set 7 | mahanoro
# Processing Record 22 of Set 7 | ocumare del tuy
# Processing Record 23 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 24 of Set 7 | walvis bay
# Processing Record 25 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 7 | dahuk
# Processing Record 27 of Set 7 | buckeye
# Processing Record 28 of Set 7 | kawalu
# Processing Record 29 of Set 7 | fergus falls
# Processing Record 30 of Set 7 | port augusta
# Processing Record 31 of Set 7 | rio gallegos
# Processing Record 32 of Set 7 | te anau
# Processing Record 33 of Set 7 | kenora
# Processing Record 34 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 7 | sooke
# Processing Record 36 of Set 7 | tosya
# Processing Record 37 of Set 7 | burnie
# Processing Record 38 of Set 7 | los llanos de aridane
# Processing Record 39 of Set 7 | mahibadhoo
# Processing Record 40 of Set 7 | urosevac
# City not found. Skipping...
# Processing Record 41 of Set 7 | surin
# Processing Record 42 of Set 7 | chuy
# Processing Record 43 of Set 7 | bogatyr
# Processing Record 44 of Set 7 | jalu
# Processing Record 45 of Set 7 | saint-augustin
# Processing Record 46 of Set 7 | ilhabela
# Processing Record 47 of Set 7 | merauke
# Processing Record 48 of Set 7 | iroquois falls
# Processing Record 49 of Set 7 | calama
# Processing Record 0 of Set 8 | saint-joseph
# Processing Record 1 of Set 8 | fortuna
# Processing Record 2 of Set 8 | edd
# Processing Record 3 of Set 8 | seymchan
# Processing Record 4 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 8 | kokkola
# Processing Record 6 of Set 8 | gedo
# Processing Record 7 of Set 8 | acapulco
# Processing Record 8 of Set 8 | pisco
# Processing Record 9 of Set 8 | mezhdurechensk
# Processing Record 10 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 8 | betulia
# Processing Record 12 of Set 8 | oranjemund
# Processing Record 13 of Set 8 | kirakira
# Processing Record 14 of Set 8 | newport
# Processing Record 15 of Set 8 | bilma
# Processing Record 16 of Set 8 | hyeres
# Processing Record 17 of Set 8 | angren
# Processing Record 18 of Set 8 | salalah
# Processing Record 19 of Set 8 | sangar
# Processing Record 20 of Set 8 | thompson
# Processing Record 21 of Set 8 | kamyshevatskaya
# Processing Record 22 of Set 8 | ulfborg
# Processing Record 23 of Set 8 | nouadhibou
# Processing Record 24 of Set 8 | bilisht
# Processing Record 25 of Set 8 | martapura
# Processing Record 26 of Set 8 | santa maria
# Processing Record 27 of Set 8 | cozumel
# Processing Record 28 of Set 8 | kinsale
# Processing Record 29 of Set 8 | vilhena
# Processing Record 30 of Set 8 | asfi
# Processing Record 31 of Set 8 | chalmette
# Processing Record 32 of Set 8 | komsomolskiy
# Processing Record 33 of Set 8 | neiafu
# Processing Record 34 of Set 8 | khrebtovaya
# Processing Record 35 of Set 8 | hamilton
# Processing Record 36 of Set 8 | eldorado
# Processing Record 37 of Set 8 | vao
# Processing Record 38 of Set 8 | aksarka
# Processing Record 39 of Set 8 | iwanai
# Processing Record 40 of Set 8 | havoysund
# Processing Record 41 of Set 8 | otjiwarongo
# Processing Record 42 of Set 8 | deputatskiy
# Processing Record 43 of Set 8 | basco
# Processing Record 44 of Set 8 | jacareacanga
# Processing Record 45 of Set 8 | seoul
# Processing Record 46 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 8 | port lincoln
# Processing Record 48 of Set 8 | sturgis
# Processing Record 49 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 0 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 9 | abaza
# Processing Record 4 of Set 9 | middle island
# Processing Record 5 of Set 9 | veraval
# Processing Record 6 of Set 9 | saint-francois
# Processing Record 7 of Set 9 | kefamenanu
# Processing Record 8 of Set 9 | port-gentil
# Processing Record 9 of Set 9 | kuruman
# Processing Record 10 of Set 9 | kahului
# Processing Record 11 of Set 9 | vila franca do campo
# Processing Record 12 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 13 of Set 9 | vung tau
# Processing Record 14 of Set 9 | beibei
# Processing Record 15 of Set 9 | sao gabriel da cachoeira
# Processing Record 16 of Set 9 | sobreira
# Processing Record 17 of Set 9 | yarim
# Processing Record 18 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 9 | akyab
# Processing Record 20 of Set 9 | yantal
# Processing Record 21 of Set 9 | hit
# Processing Record 22 of Set 9 | kalmunai
# Processing Record 23 of Set 9 | cabedelo
# Processing Record 24 of Set 9 | gannan
# Processing Record 25 of Set 9 | bubaque
# Processing Record 26 of Set 9 | katherine
# Processing Record 27 of Set 9 | vostok
# Processing Record 28 of Set 9 | kolyvan
# Processing Record 29 of Set 9 | inongo
# Processing Record 30 of Set 9 | springbok
# Processing Record 31 of Set 9 | ca mau
# Processing Record 32 of Set 9 | sola
# Processing Record 33 of Set 9 | cabo san lucas
# Processing Record 34 of Set 9 | nova vicosa
# Processing Record 35 of Set 9 | sandakan
# Processing Record 36 of Set 9 | tecoanapa
# Processing Record 37 of Set 9 | carballo
# Processing Record 38 of Set 9 | gemena
# Processing Record 39 of Set 9 | koppies
# Processing Record 40 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 41 of Set 9 | minab
# Processing Record 42 of Set 9 | ancud
# Processing Record 43 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 9 | arlit
# Processing Record 45 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 9 | aguas formosas
# Processing Record 47 of Set 9 | koundara
# Processing Record 48 of Set 9 | tazovskiy
# Processing Record 49 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 0 of Set 10 | bima
# Processing Record 1 of Set 10 | guiglo
# Processing Record 2 of Set 10 | fukue
# Processing Record 3 of Set 10 | mgachi
# Processing Record 4 of Set 10 | okato
# Processing Record 5 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | fort nelson
# Processing Record 7 of Set 10 | ratnagiri
# Processing Record 8 of Set 10 | igarka
# Processing Record 9 of Set 10 | jiwani
# Processing Record 10 of Set 10 | popondetta
# Processing Record 11 of Set 10 | fairview
# Processing Record 12 of Set 10 | kendari
# Processing Record 13 of Set 10 | tocopilla
# Processing Record 14 of Set 10 | kyaukse
# Processing Record 15 of Set 10 | bose
# Processing Record 16 of Set 10 | ziro
# Processing Record 17 of Set 10 | manggar
# Processing Record 18 of Set 10 | borogontsy
# Processing Record 19 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 10 | severo-kurilsk
# Processing Record 21 of Set 10 | morristown
# Processing Record 22 of Set 10 | avera
# Processing Record 23 of Set 10 | iisaku
# Processing Record 24 of Set 10 | mizdah
# Processing Record 25 of Set 10 | ocos
# Processing Record 26 of Set 10 | aitape
# Processing Record 27 of Set 10 | linqing
# Processing Record 28 of Set 10 | coahuayana
# Processing Record 29 of Set 10 | pantai remis
# Processing Record 30 of Set 10 | kloulklubed
# Processing Record 31 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 10 | tagab
# Processing Record 33 of Set 10 | leshukonskoye
# Processing Record 34 of Set 10 | beirut
# Processing Record 35 of Set 10 | hammerfest
# Processing Record 36 of Set 10 | nelson bay
# Processing Record 37 of Set 10 | itarema
# Processing Record 38 of Set 10 | coquimbo
# Processing Record 39 of Set 10 | prince rupert
# Processing Record 40 of Set 10 | sayyan
# Processing Record 41 of Set 10 | katima mulilo
# Processing Record 42 of Set 10 | huaidian
# Processing Record 43 of Set 10 | cayenne
# Processing Record 44 of Set 10 | krasnoborsk
# Processing Record 45 of Set 10 | zima
# Processing Record 46 of Set 10 | neuquen
# Processing Record 47 of Set 10 | comodoro rivadavia
# Processing Record 48 of Set 10 | vanimo
# Processing Record 49 of Set 10 | abonnema
# Processing Record 0 of Set 11 | poum
# Processing Record 1 of Set 11 | ningan
# City not found. Skipping...
# Processing Record 2 of Set 11 | wilmington
# Processing Record 3 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 11 | kearney
# Processing Record 5 of Set 11 | gallup
# Processing Record 6 of Set 11 | khuzhir
# Processing Record 7 of Set 11 | kholtoson
# Processing Record 8 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 9 of Set 11 | rognan
# Processing Record 10 of Set 11 | verkhnevilyuysk
# Processing Record 11 of Set 11 | akdepe
# Processing Record 12 of Set 11 | rincon
# Processing Record 13 of Set 11 | lata
# Processing Record 14 of Set 11 | mozarlandia
# Processing Record 15 of Set 11 | brae
# Processing Record 16 of Set 11 | najran
# Processing Record 17 of Set 11 | ambilobe
# Processing Record 18 of Set 11 | la ronge
# Processing Record 19 of Set 11 | afua
# Processing Record 20 of Set 11 | ossora
# Processing Record 21 of Set 11 | caracollo
# Processing Record 22 of Set 11 | bharatpur
# Processing Record 23 of Set 11 | pervomayskoye
# Processing Record 24 of Set 11 | garachine
# Processing Record 25 of Set 11 | buala
# Processing Record 26 of Set 11 | sinnamary
# Processing Record 27 of Set 11 | xianshuigu
# Processing Record 28 of Set 11 | wajid
# Processing Record 29 of Set 11 | kristiansand
# Processing Record 30 of Set 11 | flinders
# Processing Record 31 of Set 11 | carlyle
# Processing Record 32 of Set 11 | harer
# Processing Record 33 of Set 11 | saint george
# Processing Record 34 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 35 of Set 11 | presidencia roque saenz pena
# Processing Record 36 of Set 11 | yulara
# Processing Record 37 of Set 11 | bastrop
# Processing Record 38 of Set 11 | zhigansk
# Processing Record 39 of Set 11 | lagoa
# Processing Record 40 of Set 11 | vysokogornyy
# Processing Record 41 of Set 11 | lahat
# Processing Record 42 of Set 11 | kumukh
# Processing Record 43 of Set 11 | makakilo city
# Processing Record 44 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 11 | vuktyl
# Processing Record 46 of Set 11 | riyadh
# Processing Record 47 of Set 11 | monroe
# Processing Record 48 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 49 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 0 of Set 12 | san patricio
# Processing Record 1 of Set 12 | daru
# Processing Record 2 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 12 | samarai
# Processing Record 4 of Set 12 | sibu
# Processing Record 5 of Set 12 | khotyn
# Processing Record 6 of Set 12 | nyimba
# Processing Record 7 of Set 12 | brownfield
# Processing Record 8 of Set 12 | emiliano zapata
# Processing Record 9 of Set 12 | banda aceh
# Processing Record 10 of Set 12 | magadan
# Processing Record 11 of Set 12 | praia da vitoria
# Processing Record 12 of Set 12 | gawler
# Processing Record 13 of Set 12 | puerto del rosario
# Processing Record 14 of Set 12 | belinskiy
# Processing Record 15 of Set 12 | luau
# Processing Record 16 of Set 12 | port blair
# Processing Record 17 of Set 12 | channel-port aux basques
# Processing Record 18 of Set 12 | gamboma
# Processing Record 19 of Set 12 | gat
# Processing Record 20 of Set 12 | khandagayty
# Processing Record 21 of Set 12 | fare
# Processing Record 22 of Set 12 | honningsvag
# Processing Record 23 of Set 12 | gravdal
# Processing Record 24 of Set 12 | doha
# Processing Record 25 of Set 12 | le port
# Processing Record 26 of Set 12 | kangaatsiaq
# Processing Record 27 of Set 12 | sesimbra
# Processing Record 28 of Set 12 | dinghai
# Processing Record 29 of Set 12 | belchatow
# Processing Record 30 of Set 12 | flin flon
# Processing Record 31 of Set 12 | balabac
# Processing Record 32 of Set 12 | tynda
# Processing Record 33 of Set 12 | ko samui
# Processing Record 34 of Set 12 | urucui
# Processing Record 35 of Set 12 | kulhudhuffushi
# Processing Record 36 of Set 12 | hobyo
# Processing Record 37 of Set 12 | pangnirtung
# Processing Record 38 of Set 12 | agirish
# Processing Record 39 of Set 12 | gisborne
# Processing Record 40 of Set 12 | krivosheino
# Processing Record 41 of Set 12 | daphne
# Processing Record 42 of Set 12 | deder
# Processing Record 43 of Set 12 | kieta
# Processing Record 44 of Set 12 | lahaina
# Processing Record 45 of Set 12 | santa barbara
# Processing Record 46 of Set 12 | numaligarh
# Processing Record 47 of Set 12 | itapirapua
# Processing Record 48 of Set 12 | wonogiri
# Processing Record 49 of Set 12 | menongue
# Processing Record 0 of Set 13 | nyurba
# Processing Record 1 of Set 13 | kamenka
# Processing Record 2 of Set 13 | kamaishi
# Processing Record 3 of Set 13 | bela vista de goias
# Processing Record 4 of Set 13 | lucea
# Processing Record 5 of Set 13 | savonlinna
# Processing Record 6 of Set 13 | hauge
# Processing Record 7 of Set 13 | kiruna
# Processing Record 8 of Set 13 | alyangula
# Processing Record 9 of Set 13 | hervey bay
# Processing Record 10 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 13 | maloy
# Processing Record 12 of Set 13 | yarada
# Processing Record 13 of Set 13 | cubuk
# Processing Record 14 of Set 13 | milkovo
# Processing Record 15 of Set 13 | imbituba
# Processing Record 16 of Set 13 | korla
# Processing Record 17 of Set 13 | port-cartier
# Processing Record 18 of Set 13 | areosa
# Processing Record 19 of Set 13 | pilar
# Processing Record 20 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 21 of Set 13 | mandurah
# Processing Record 22 of Set 13 | itaituba
# Processing Record 23 of Set 13 | bocaiuva
# Processing Record 24 of Set 13 | nabinagar
# Processing Record 25 of Set 13 | vavozh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)  

# Show Record Count
city_data_df.count(0)
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      rikitea -23.1203 -134.9692     76.95        69          24       12.08
# 1        isiro   2.7739   27.6160     79.38        60         100        3.15
# 2        sitka  57.0531 -135.3300     39.09        65         100        8.05
# 3  yellowknife  62.4560 -114.3525     16.32        73          75       11.50
# 4      ahipara -35.1667  173.1667     64.40        87          25       12.97
#
#   Country        Date
# 0      PF  1681314365
# 1      CD  1681314365
# 2      US  1681314365
# 3      CA  1681314366
# 4      NZ  1681314366

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            rikitea -23.1203 -134.9692     76.95        69          24
# 1              isiro   2.7739   27.6160     79.38        60         100
# 2              sitka  57.0531 -135.3300     39.09        65         100
# 3        yellowknife  62.4560 -114.3525     16.32        73          75
# 4            ahipara -35.1667  173.1667     64.40        87          25
#
#          Wind Speed Country        Date
# City_ID
# 0             12.08      PF  1681314365
# 1              3.15      CD  1681314365
# 2              8.05      US  1681314365
# 3             11.50      CA  1681314366
# 4             12.97      NZ  1681314366

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
l_values = city_data_df["Lat"]      
t_values = city_data_df["Max Temp"]     
plt.scatter(l_values,t_values)
plt.title("City Max Latitude vs.Temperature" + time.strftime("%x"))    
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)
             

# Incorporate the other graph properties
  

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
l_values = city_data_df["Lat"]
h_values = city_data_df["Humidity"]
plt.scatter(l_values,h_values)
plt.title("City Latitude vs. Humidity" + time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Incorporate the other graph properties


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
l= city_data_df["Lat"]
c= city_data_df["Cloudiness"]
plt.scatter(l,c)
plt.title("City Latitude vs. Cloudiness" + time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
l= city_data_df["Lat"]
w= city_data_df["Wind Speed"]
plt.scatter(l,w)
plt.title("City Latitude vs. Wind Speed" + time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
        # Run regression on hemisphere weather data
        (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
        # Calculate the regression line "y values" from the slope and intercept
        regress_values = x_values * slope + intercept
        line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
        # Create a scatter plot and plot the regression line
        plt.scatter(x_values,y_values)
        plt.plot(x_values,regress_values,"r")
        
        # Annotate the text for the line equation
        plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
        plt.xlabel('Latitude')
        plt.ylabel(y_label)
        plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              isiro   2.7739   27.6160     79.38        60         100
# 2              sitka  57.0531 -135.3300     39.09        65         100
# 3        yellowknife  62.4560 -114.3525     16.32        73          75
# 6           khatanga  71.9667  102.5000     17.06        79         100
# 7         nikolskoye  59.7035   30.7861     55.29        75          15
#
#          Wind Speed Country        Date
# City_ID
# 1              3.15      CD  1681314365
# 2              8.05      US  1681314365
# 3             11.50      CA  1681314366
# 6             27.04      RU  1681314366
# 7              7.70      RU  1681314366

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        rikitea -23.1203 -134.9692     76.95        69          24
# 4        ahipara -35.1667  173.1667     64.40        87          25
# 5           lebu -37.6167  -73.6500     56.89        90         100
# 8         hobart -42.8794  147.3294     57.06        95         100
# 11         jutai  -5.1833  -68.9000     85.01        66         100
#
#          Wind Speed Country        Date
# City_ID
# 0             12.08      PF  1681314365
# 4             12.97      NZ  1681314366
# 5              9.06      CL  1681314366
# 8              0.00      AU  1681314079
# 11             2.86      BR  1681314367

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype('float')
y_values = northern_hemi_df["Max Temp"].astype('float') 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
print (f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7305096741274083

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype('float')
y_values = southern_hemi_df["Max Temp"].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
print (f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5292050815546702

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype('float')
y_values = northern_hemi_df["Humidity"].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print (f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.1071020555253316

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype('float')

y_values = southern_hemi_df["Humidity"].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print (f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype('float')
y_values = northern_hemi_df["Cloudiness"].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print (f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.02753965355174336

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype('float')
y_values = southern_hemi_df["Cloudiness"].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print (f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.03476533989831334

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype('float')
y_values = northern_hemi_df["Wind Speed"].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print (f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00722234216762581

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype('float')
y_values = southern_hemi_df["Wind Speed"].astype('float')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print (f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#The measuments are not very strong, but there is a slight correlation between latitude and max temperature. 
#The closer to the equator, the higher the max temperature. The correlation between latitude and humidity is not very strong.
